# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_or = pd.read_csv('datasets/OrderReports.csv')
df_or.head()
# Out:
#                   Date  Order # N. Revenue (formatted)      Status  \
# 0  2023-10-26 14:50:17  16698.0                RM57.80  processing
# 1  2023-10-26 13:53:47  16697.0                RM32.90  processing
# 2  2023-10-26 13:04:17  16696.0                RM32.90  processing
# 3  2023-10-26 13:00:49  16695.0                RM82.70  processing
# 4  2023-10-26 12:47:36  16694.0                RM32.90  processing
#
#                                Customer Customer type  \
# 0  AINAA SYAFIQAH ABD RAHMAN ABD RAHMAN           new
# 1                              Ja Hasim           new
# 2                             nasy anis           new
# 3   Herny erdawati binti Mohamad Rashed           new
# 4                      Suhaina Sulaiman           new
#
#                                           Product(s)  Items sold  N. Revenue  \
# 0  1× LIP BOOSTER - WATERMELON, 1× LIP BOOSTER - ...         2.0        49.8
# 1                             1× LIP BOOSTER - MELON         1.0        24.9
# 2                             1× LIP BOOSTER - MELON         1.0        24.9
# 3  1× LIP BOOSTER - STRAWBERRY, 2× LIP BOOSTER - ...         3.0        74.7
# 4                        1× LIP BOOSTER - WATERMELON         1.0        24.9
#
#       State  Age Gender
# 0     Perak   36      F
# 1     Johor   25      F
# 2    Melaka   31      F
# 3  Kelantan   31      F
# 4    Perlis   38      F

# %%
df_or.columns
# Out:
# Index(['Date', 'Order #', 'N. Revenue (formatted)', 'Status', 'Customer',
#        'Customer type', 'Product(s)', 'Items sold', 'N. Revenue', 'State',
#        'Age', 'Gender'],
#       dtype='object')

# %%
df_or.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8014 entries, 0 to 8013
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    8014 non-null   object
#  1   Order #                 8014 non-null   float64
#  2   N. Revenue (formatted)  8014 non-null   object
#  3   Status                  8014 non-null   object
#  4   Customer                8014 non-null   object
#  5   Customer type           8014 non-null   object
#  6   Product(s)              8014 non-null   object
#  7   Items sold              8014 non-null   float64
#  8   N. Revenue              8014 non-null   float64
#  9   State                   8014 non-null   object
#  10  Age                     8014 non-null   int64
#  11  Gender                  8014 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 751.4+ KB

# %% [markdown]
# # **Total Items Sold by State**

# %%
df_or['Items sold'] = df_or['Items sold'].astype(int)

# %%
total_sales_by_state = df_or.groupby('State')['Items sold'].sum().reset_index()

# %%
for index, row in total_sales_by_state.iterrows():
    state = row['State']
    total_items_sold = row['Items sold']
    print(f"State {state} total sales = {total_items_sold}")
# Out:
# State Johor total sales = 1604
# State Kedah total sales = 1401
# State Kelantan total sales = 1219
# State Labuan total sales = 23
# State Melaka total sales = 1708
# State Negeri Sembilan total sales = 1566
# State Pahang total sales = 1221
# State Penang total sales = 753
# State Perak total sales = 1086
# State Perlis total sales = 1419
# State Putrajaya total sales = 165
# State Sabah total sales = 44
# State Sarawak total sales = 49
# State Selangor total sales = 2159
# State Terengganu total sales = 1036
# State WP Kuala Lumpur total sales = 569

# %%
plt.figure(figsize=(25, 10))
plt.bar(total_sales_by_state['State'], total_sales_by_state['Items sold'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Total Sales by State')
plt.show()

# %% [markdown]
# # **Total Revenue by State**

# %%
df_or['N. Revenue'] = df_or['N. Revenue'].astype(int)

# %%
total_revenue_by_state = df_or.groupby('State')['N. Revenue'].sum().reset_index()

for index, row in total_revenue_by_state.iterrows():
    state = row['State']
    total_revenue = row['N. Revenue']
    print(f"State {state} total revenue = {total_revenue}")
# Out:
# State Johor total revenue = 47977
# State Kedah total revenue = 39942
# State Kelantan total revenue = 35953
# State Labuan total revenue = 742
# State Melaka total revenue = 49134
# State Negeri Sembilan total revenue = 45988
# State Pahang total revenue = 36728
# State Penang total revenue = 21497
# State Perak total revenue = 32429
# State Perlis total revenue = 40964
# State Putrajaya total revenue = 4846
# State Sabah total revenue = 1301
# State Sarawak total revenue = 1206
# State Selangor total revenue = 64205
# State Terengganu total revenue = 30965
# State WP Kuala Lumpur total revenue = 16064

# %%
plt.figure(figsize=(25, 10))
plt.bar(total_revenue_by_state['State'], total_revenue_by_state['N. Revenue'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Total Revenue')
plt.title('Total Sales by State')
plt.show()

# %% [markdown]
# # **Total items sold by age**

# %%
age = df_or['Age']
total_sales_by_age = df_or.groupby('Age')['Items sold'].sum().reset_index()

for index, row in total_sales_by_age.iterrows():
    ages = row['Age']
    total_items_sold = row['Items sold']
    print(f"Age {ages} total sales = {total_items_sold}")
# Out:
# Age 25 total sales = 506
# Age 26 total sales = 632
# Age 27 total sales = 622
# Age 28 total sales = 661
# Age 29 total sales = 560
# Age 30 total sales = 526
# Age 31 total sales = 1175
# Age 32 total sales = 1209
# Age 33 total sales = 1124
# Age 34 total sales = 1357
# Age 35 total sales = 1108
# Age 36 total sales = 1181
# Age 37 total sales = 683
# Age 38 total sales = 573
# Age 39 total sales = 564
# Age 40 total sales = 607
# Age 41 total sales = 653
# Age 42 total sales = 567
# Age 43 total sales = 514
# Age 44 total sales = 578
# Age 45 total sales = 622

# %%
plt.figure(figsize=(25, 10))
plt.bar(total_sales_by_age['Age'], total_sales_by_age['Items sold'], color='skyblue')
plt.xlabel('Age')
plt.ylabel('Total Sales')
plt.title('Total Sales by Age')
plt.show()

# %% [markdown]
# # **Total Revenue by Age**

# %%
total_revenue_by_age = df_or.groupby('Age')['N. Revenue'].sum().reset_index()

for index, row in total_revenue_by_age.iterrows():
    ages = row['Age']
    total_revenue = row['N. Revenue']
    print(f"Age {ages} total revenue = {total_revenue}")
# Out:
# Age 25 total revenue = 14875
# Age 26 total revenue = 19517
# Age 27 total revenue = 18011
# Age 28 total revenue = 18571
# Age 29 total revenue = 15937
# Age 30 total revenue = 16123
# Age 31 total revenue = 33620
# Age 32 total revenue = 35247
# Age 33 total revenue = 32458
# Age 34 total revenue = 41297
# Age 35 total revenue = 31920
# Age 36 total revenue = 35080
# Age 37 total revenue = 19821
# Age 38 total revenue = 16410
# Age 39 total revenue = 16806
# Age 40 total revenue = 18992
# Age 41 total revenue = 18970
# Age 42 total revenue = 16405
# Age 43 total revenue = 14723
# Age 44 total revenue = 17537
# Age 45 total revenue = 17621

# %%
plt.figure(figsize=(25, 10))
plt.bar(total_revenue_by_age['Age'], total_revenue_by_age['N. Revenue'], color='skyblue')
plt.xlabel('Age')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Age')
plt.show()

# %% [markdown]
# # **Prediction for next year's revenue based on state and age**

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df_or['State'] = label_encoder.fit_transform(df_or['State'])
df_or['Gender'] = label_encoder.fit_transform(df_or['Gender'])
df_or['Customer type'] = label_encoder.fit_transform(df_or['Customer type'])
df_or.head()
# Out:
#                   Date  Order # N. Revenue (formatted)      Status  \
# 0  2023-10-26 14:50:17  16698.0                RM57.80  processing
# 1  2023-10-26 13:53:47  16697.0                RM32.90  processing
# 2  2023-10-26 13:04:17  16696.0                RM32.90  processing
# 3  2023-10-26 13:00:49  16695.0                RM82.70  processing
# 4  2023-10-26 12:47:36  16694.0                RM32.90  processing
#
#                                Customer  Customer type  \
# 0  AINAA SYAFIQAH ABD RAHMAN ABD RAHMAN              0
# 1                              Ja Hasim              0
# 2                             nasy anis              0
# 3   Herny erdawati binti Mohamad Rashed              0
# 4                      Suhaina Sulaiman              0
#
#                                           Product(s)  Items sold  N. Revenue  \
# 0  1× LIP BOOSTER - WATERMELON, 1× LIP BOOSTER - ...           2          49
# 1                             1× LIP BOOSTER - MELON           1          24
# 2                             1× LIP BOOSTER - MELON           1          24
# 3  1× LIP BOOSTER - STRAWBERRY, 2× LIP BOOSTER - ...           3          74
# 4                        1× LIP BOOSTER - WATERMELON           1          24
#
#    State  Age  Gender
# 0      8   36       0
# 1      0   25       0
# 2      4   31       0
# 3      2   31       0
# 4      9   38       0

# %%
correlation = df_or.corr()
correlation
# Out:
# /var/folders/t7/d2wdwfpn2bx5mfnm12djdfmc0000gn/T/ipykernel_55032/3611753651.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df_or.corr()
#                 Order #  Customer type  Items sold  N. Revenue     State  \
# Order #        1.000000       0.099050   -0.084797   -0.004114  0.009881
# Customer type  0.099050       1.000000    0.035785    0.075878  0.003157
# Items sold    -0.084797       0.035785    1.000000    0.914383  0.003234
# N. Revenue    -0.004114       0.075878    0.914383    1.000000  0.003794
# State          0.009881       0.003157    0.003234    0.003794  1.000000
# Age            0.010642       0.001572    0.002437    0.002180  0.984292
# Gender         0.000831      -0.001994   -0.001941    0.003357  0.000308
#
#                     Age    Gender
# Order #        0.010642  0.000831
# Customer type  0.001572 -0.001994
# Items sold     0.002437 -0.001941
# N. Revenue     0.002180  0.003357
# State          0.984292  0.000308
# Age            1.000000  0.002417
# Gender         0.002417  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='RdYlBu', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X = df_or.drop(columns=['Order #','Date','Status', 'N. Revenue (formatted)','N. Revenue','Product(s)', 'Customer' ])
y = df_or['N. Revenue']
X.head()
# Out:
#    Customer type  Items sold  State  Age  Gender
# 0              0           2      8   36       0
# 1              0           1      0   25       0
# 2              0           1      4   31       0
# 3              0           3      2   31       0
# 4              0           1      9   38       0

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction_test = model.predict(X_test)
prediction_train = model.predict(X_train)

# %%
from sklearn.metrics import r2_score

r2_train = r2_score(y_train, prediction_train)
print(f"R2 Score: {r2_train}")
# Out:
# R2 Score: 0.6866151114970093

# %%
r2_test = r2_score(y_test, prediction_test)
print(f"R2 Score: {r2_test}")
# Out:
# R2 Score: 0.9349657925083531

# %%
last_year_sales = 553765
growth_rate = 0.10

# Project sales for next year
projected_total_sales = last_year_sales * (1 + growth_rate)

print(f"Projected sales for next year: {projected_total_sales}")
# Out:
# Projected sales for next year: 609141.5

# %%
for index, row in total_revenue_by_age.iterrows():
    age = row['Age']
    total_revenue = row['N. Revenue']
    projected_sales = total_revenue * (1 + growth_rate)
    print(f"Projected sales for Age {age} for next year: {projected_sales}")
# Out:
# Projected sales for Age 25 for next year: 16362.500000000002
# Projected sales for Age 26 for next year: 21468.7
# Projected sales for Age 27 for next year: 19812.100000000002
# Projected sales for Age 28 for next year: 20428.100000000002
# Projected sales for Age 29 for next year: 17530.7
# Projected sales for Age 30 for next year: 17735.300000000003
# Projected sales for Age 31 for next year: 36982.0
# Projected sales for Age 32 for next year: 38771.700000000004
# Projected sales for Age 33 for next year: 35703.8
# Projected sales for Age 34 for next year: 45426.700000000004
# Projected sales for Age 35 for next year: 35112.0
# Projected sales for Age 36 for next year: 38588.0
# Projected sales for Age 37 for next year: 21803.100000000002
# Projected sales for Age 38 for next year: 18051.0
# Projected sales for Age 39 for next year: 18486.600000000002
# Projected sales for Age 40 for next year: 20891.2
# Projected sales for Age 41 for next year: 20867.0
# Projected sales for Age 42 for next year: 18045.5
# Projected sales for Age 43 for next year: 16195.300000000001
# Projected sales for Age 44 for next year: 19290.7
# Projected sales for Age 45 for next year: 19383.100000000002

# %%
projected_sales = [(total_revenue * (1 + growth_rate)) for total_revenue in total_revenue_by_age['N. Revenue']]

# Visualize the projected sales for each age group
plt.figure(figsize=(10, 6))

plt.bar(total_revenue_by_age['Age'], projected_sales, alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Projected Sales for Next Year')
plt.title('Projected Sales by Age for Next Year')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
